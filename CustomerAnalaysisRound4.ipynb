# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"c:\Users\usuario\Downloads\merged_clean_ver1.csv")

# %%
def2 = pd.read_csv(r"c:\Users\usuario\Downloads\merged_clean_ver2.csv")

# %%
pip install pandas seaborn matplotlib
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.3 kB ? eta -:--:--
#      ----------------------------------- -- 153.6/162.3 kB 4.6 MB/s eta 0:00:01
#      -------------------------------------- 162.3/162.3 kB 1.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ------------------------------------- - 286.7/294.9 kB 17.3 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 6.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.6 MB 9.6 MB/s eta 0:00:01
#    --- ------------------------------------ 0.7/7.6 MB 8.9 MB/s eta 0:00:01
#    ------- -------------------------------- 1.4/7.6 MB 10.9 MB/s eta 0:00:01
#    --------- ------------------------------ 1.8/7.6 MB 10.4 MB/s eta 0:00:01
# ...

# %%
def2.head()
# Out:
#    Unnamed: 0      id state  gender  median_home_val  median_household_income  \
# 0           0   44060    FL    Male      1158.437751                      392
# 1           1   96093    IL    Male       537.000000                      365
# 2           2   43333    FL  Female       725.000000                      301
# 3           3   21885    NC    Male      1158.437751                      401
# 4           4  190108    FL  Female       995.000000                      252
#
#      ic2  ic3    ic4      ic5    avggift  target_d      ic2_
# 0  430.0  466  520.0  21975.0  28.000000     100.0  Moderate
# 1  415.0  410  473.0  19387.0   5.666667       7.0  Moderate
# 2  340.0  361  436.0  18837.0   4.111111       5.0       Low
# 3  407.0  399  413.0  14014.0  27.277778      38.0  Moderate
# 4  280.0  316  348.0  17991.0   6.000000       5.0       Low
